# %% [markdown]
# ## Horovod Distributed Training with Script Mode.

# %% [markdown]
# ### Setup

# %%
import sagemaker
import os
from sagemaker.utils import sagemaker_timestamp
from sagemaker.tensorflow import TensorFlow

sage_session = sagemaker.Session()

from sagemaker import get_execution_role
role = get_execution_role()


account = sage_session.boto_session.client('sts').get_caller_identity()['Account']
region = sage_session.boto_session.region_name

image_name = "sagemaker-horovod-distributed-training-3"
ecr_image_url = '{}.dkr.ecr.{}.amazonaws.com/{}:latest'.format(account, region,image_name)

# %% [markdown]
# ### Build your horovod container

# %%
# %%script env region=$region image_name=$image_name bash
#
# echo "Building docker image locally with image name: $image_name region: $region"
#
# # Sagemaker Registry account id
# sagemaker_registry_account=520713654638
#
# # Get the login command from ECR and execute it directly with registy id of sagemaker to extend the sagemaker TF container.
# $(aws ecr get-login --region ${region} --no-include-email --registry-ids ${sagemaker_registry_account})
#
# # Build the docker image locally with the image name and then push it to ECR.
#
# # On a SageMaker Notebook Instance, the docker daemon may need to be restarted in order
# # to detect your network configuration correctly.  (This is a known issue.)
# if [ -d "/home/ec2-user/SageMaker" ]; then
#   sudo service docker restart
# fi
#
# cd ../ && docker build -t ${image_name}:latest --build-arg region=${region} -f docker/Dockerfile.cpu .
# Out:
# Building docker image locally with image name: sagemaker-horovod-distributed-training-3 region: us-west-2
# Login Succeeded
# Sending build context to Docker daemon  648.1MB
# Step 1/22 : ARG region
# Step 2/22 : FROM 520713654638.dkr.ecr.$region.amazonaws.com/sagemaker-tensorflow-scriptmode:1.11.0-cpu-py3
#  ---> 17315c52418a
# Step 3/22 : RUN echo $region
#  ---> Using cache
#  ---> fe5d9732736e
# Step 4/22 : RUN buildDeps="         wget         build-essential     "     && apt-get update && apt-get install -y --no-install-recommends $buildDeps     && apt-get clean     && rm -rf /var/lib/apt/lists/*
#  ---> Using cache
#  ---> f0582b469428
# Step 5/22 : RUN mkdir /tmp/openmpi &&     cd /tmp/openmpi &&     wget https://www.open-mpi.org/software/ompi/v3.0/downloads/openmpi-3.0.0.tar.gz &&     tar zxf openmpi-3.0.0.tar.gz &&     cd openmpi-3.0.0 &&     ./configure --enable-orterun-prefix-by-default &&     make -j $(nproc) all &&     make install &&     ldconfig &&     rm -rf /tmp/openmpi
#  ---> Using cache
#  ---> 7399858657a0
# Step 6/22 : RUN ldconfig /usr/local/cuda-9.0/targets/x86_64-linux/lib/stubs &&     HOROVOD_CPU_ALLREDUCE=MPI HOROVOD_WITH_TENSORFLOW=1 pip install --no-cache-dir horovod &&     ldconfig
#  ---> Using cache
#  ---> 68129cc8c868
# Step 7/22 : RUN mv /usr/local/bin/mpirun /usr/local/bin/mpirun.real &&     echo '#!/bin/bash' > /usr/local/bin/mpirun &&     echo 'mpirun.real --allow-run-as-root "$@"' >> /usr/local/bin/mpirun &&     chmod a+x /usr/local/bin/mpirun
#  ---> Using cache
#  ---> 007b6aea3ca8
# Step 8/22 : RUN echo "hwloc_base_binding_policy = none" >> /usr/local/etc/openmpi-mca-params.conf &&     echo "rmaps_base_mapping_policy = slot" >> /usr/local/etc/openmpi-mca-params.conf
#  ---> Using cache
#  ---> b8fde97a1306
# Step 9/22 : ENV LD_LIBRARY_PATH=/usr/local/openmpi/lib:$LD_LIBRARY_PATH
#  ---> Using cache
#  ---> 567126237786
# Step 10/22 : ENV PATH /usr/local/openmpi/bin/:$PATH
#  ---> Using cache
#  ---> 99747350a94b
# Step 11/22 : ENV PATH=/usr/local/nvidia/bin:$PATH
#  ---> Using cache
#  ---> 9a5e214178d5
# Step 12/22 : ENV PYTHONDONTWRITEBYTECODE=1 PYTHONUNBUFFERED=1
#  ---> Using cache
#  ---> 034c8db404ad
# Step 13/22 : RUN apt-get update && apt-get install -y --no-install-recommends openssh-server &&     mkdir -p /var/run/sshd
#  ---> Using cache
#  ---> 79f6f5805f8d
# Step 14/22 : RUN sed 's@session\s*required\s*pam_loginuid.so@session optional pam_loginuid.so@g' -i /etc/pam.d/sshd
#  ---> Using cache
#  ---> bf42239dd1d1
# Step 15/22 : RUN mkdir -p /root/.ssh/ &&   ssh-keygen -q -t rsa -N '' -f /root/.ssh/id_rsa &&   cp /root/.ssh/id_rsa.pub /root/.ssh/authorized_keys &&   printf "Host *\n  StrictHostKeyChecking no\n" >> /root/.ssh/config
#  ---> Using cache
#  ---> 44f50ea713e9
# Step 16/22 : COPY docker/resources/changehostname.c /
#  ---> Using cache
#  ---> 6c9882a9e31c
# Step 17/22 : COPY docker/resources/change-hostname.sh /
#  ---> Using cache
#  ---> 10a09de97294
# Step 18/22 : COPY docker/resources/change-hostname.sh /usr/local/bin/change-hostname.sh
#  ---> Using cache
#  ---> e66f5b31acfa
# Step 19/22 : RUN chmod +x /usr/local/bin/change-hostname.sh
#  ---> Using cache
#  ---> 488a6273a138
# Step 20/22 : RUN chmod +x /change-hostname.sh
#  ---> Using cache
#  ---> 83c16e26f670
# Step 21/22 : RUN pip install keras
#  ---> Using cache
#  ---> a7a06a3871f9
# Step 22/22 : RUN pip install retrying
#  ---> Using cache
#  ---> 0813e008623a
# Successfully built 0813e008623a
# Successfully tagged sagemaker-horovod-distributed-training-3:latest
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.

# %% [markdown]
# ## Push container to ECR Repository

# %%
# %%script env account=$account region=$region image_name=$image_name ecr_image_url=$ecr_image_url bash
#
# echo "Pushing locally built container to ECR Repository: $ecr_image_url in region: $region on account: $account"
#
# # If the repository doesn't exist in ECR, create it.
# aws ecr describe-repositories --repository-names "${image_name}" > /dev/null 2>&1
#
# if [ $? -ne 0 ]
# then
#     echo "Creating a new ECR repository with name: $image_name"
#     aws ecr create-repository --repository-name "${image_name}" > /dev/null
# fi
#
# `aws ecr get-login --no-include-email --region ${region}`
#
# # Tag Docker image with ECR Url
# docker tag ${image_name}:latest ${ecr_image_url}
#
# docker push ${ecr_image_url}
# Out:
# Pushing locally built container to ECR Repository: 964029418868.dkr.ecr.us-west-2.amazonaws.com/sagemaker-horovod-distributed-training-3:latest in region: us-west-2 on account: 964029418868
# Login Succeeded
# The push refers to repository [964029418868.dkr.ecr.us-west-2.amazonaws.com/sagemaker-horovod-distributed-training-3]
# f6eb9e5c770f: Preparing
# 3680749cb7a0: Preparing
# aeae555763dc: Preparing
# 2b8e8a00654a: Preparing
# 5bbd8e9cabab: Preparing
# 4ec6682fc14e: Preparing
# 8d48a09d9821: Preparing
# 9552ffea3be9: Preparing
# 2accf753bc6e: Preparing
# 55151b854b91: Preparing
# fd4655c217ad: Preparing
# 703f7275ec5e: Preparing
# 159af601bde7: Preparing
# 9d82ea0cc0c8: Preparing
# a7024ca0e69b: Preparing
# 296294040c48: Preparing
# 302af95b9e68: Preparing
# 0ecacb4d5bb1: Preparing
# d6db7d05e3b2: Preparing
# 8d999119430c: Preparing
# fe4ed9a0e78a: Preparing
# 3db5746c911a: Preparing
# 819a824caf70: Preparing
# 647265b9d8bc: Preparing
# 41c002c8a6fd: Preparing
# f6eb9e5c770f: Waiting
# 3680749cb7a0: Waiting
# aeae555763dc: Waiting
# 2b8e8a00654a: Waiting
# 5bbd8e9cabab: Waiting
# 4ec6682fc14e: Waiting
# 8d48a09d9821: Waiting
# 9552ffea3be9: Waiting
# 2accf753bc6e: Waiting
# 55151b854b91: Waiting
# fd4655c217ad: Waiting
# 703f7275ec5e: Waiting
# 159af601bde7: Waiting
# 9d82ea0cc0c8: Waiting
# a7024ca0e69b: Waiting
# 296294040c48: Waiting
# 302af95b9e68: Waiting
# 0ecacb4d5bb1: Waiting
# d6db7d05e3b2: Waiting
# 8d999119430c: Waiting
# fe4ed9a0e78a: Waiting
# 3db5746c911a: Waiting
# 819a824caf70: Waiting
# 647265b9d8bc: Waiting
# 41c002c8a6fd: Waiting
# f6eb9e5c770f: Layer already exists
# 3680749cb7a0: Layer already exists
# aeae555763dc: Layer already exists
# 2b8e8a00654a: Layer already exists
# 5bbd8e9cabab: Layer already exists
# 4ec6682fc14e: Layer already exists
# 8d48a09d9821: Layer already exists
# 9552ffea3be9: Layer already exists
# 2accf753bc6e: Layer already exists
# 55151b854b91: Layer already exists
# fd4655c217ad: Layer already exists
# 703f7275ec5e: Layer already exists
# 159af601bde7: Layer already exists
# 9d82ea0cc0c8: Layer already exists
# a7024ca0e69b: Layer already exists
# 296294040c48: Layer already exists
# 302af95b9e68: Layer already exists
# 0ecacb4d5bb1: Layer already exists
# d6db7d05e3b2: Layer already exists
# 8d999119430c: Layer already exists
# fe4ed9a0e78a: Layer already exists
# 3db5746c911a: Layer already exists
# 819a824caf70: Layer already exists
# 647265b9d8bc: Layer already exists
# 41c002c8a6fd: Layer already exists
# latest: digest: sha256:1b6391fd157c71d0f6a4d59f30fa88c22eb2337de0414281a8d09f7ce2f1a540 size: 5552
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.

# %% [markdown]
# ### Prepare train and test data

# %%
def _get_train_test_data(data_path, sagemaker_session):

    prefix = 'tf_mnist/{}'.format(sagemaker_timestamp())
    train_data_path = os.path.join(data_path, 'train')
    key_prefix = prefix + '/train'
    train_input = sagemaker_session.upload_data(path=train_data_path, key_prefix=key_prefix)
    test_path = os.path.join(data_path, 'test')
    test_input = sagemaker_session.upload_data(path=test_path, key_prefix=prefix + '/test')

    return test_input, train_input

source_dir = os.path.join('../src')
data_path = os.path.join(source_dir, 'data')

test_input, train_input = _get_train_test_data(data_path, sage_session)

# %% [markdown]
# ### Train it with Horovod

# %%
instance_count = 12
estimator = TensorFlow(entry_point="horovod_launcher.py",
                       role=role,
                       training_steps=1,
                       evaluation_steps=1,
                       train_instance_count=instance_count,
                       train_instance_type="ml.c4.xlarge",
                       sagemaker_session=sage_session,
                       image_name=ecr_image_url,
                       base_job_name="tf-horovod-{}x".format(str(instance_count)),
                       source_dir=source_dir)

estimator.fit({'train': train_input, 'test': test_input})
# Out:
# WARNING:sagemaker:In an upcoming version of the SageMaker Python SDK, framework_version will be required to create an estimator. Please add framework_version=1.11 to your constructor to avoid an error in the future.
# INFO:sagemaker:Creating training-job with name: tf-horovod-12x-2018-11-25-11-19-08-954
# 2018-11-25 11:19:28 Starting - Starting the training job...
# 2018-11-25 11:19:31 Starting - Launching requested ML instances......
# 2018-11-25 11:20:39 Starting - Preparing the instances for training......
# 2018-11-25 11:21:51 Downloading - Downloading input data...
# 2018-11-25 11:22:06 Training - Downloading the training image..
# 2018-11-25 11:22:40,335 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2018-11-25 11:22:40,338 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-25 11:22:40,753 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-25 11:22:40,765 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_requirements": ""
#     },
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-9",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4",
#         "algo-5",
#         "algo-6",
#         "algo-7",
#         "algo-8",
#         "algo-9",
#         "algo-10",
#         "algo-11",
#         "algo-12"
#     ],
#     "hyperparameters": {
#         "evaluation_steps": 1,
#         "checkpoint_path": "s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints",
#         "training_steps": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "job_name": "tf-horovod-12x-2018-11-25-11-19-08-954",
#     "log_level": 20,
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz",
#     "module_name": "horovod_launcher",
#     "network_interface_name": "ethwe",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "resource_config": {
#         "current_host": "algo-9",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3",
#             "algo-4",
#             "algo-5",
#             "algo-6",
#             "algo-7",
#             "algo-8",
#             "algo-9",
#             "algo-10",
#             "algo-11",
#             "algo-12"
#         ],
#         "network_interface_name": "ethwe"
#     },
#     "user_entry_point": "horovod_launcher.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"]
# SM_NETWORK_INTERFACE_NAME=ethwe
# SM_HPS={"checkpoint_path":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","evaluation_steps":1,"training_steps":1}
# SM_USER_ENTRY_POINT=horovod_launcher.py
# SM_FRAMEWORK_PARAMS={"sagemaker_requirements":""}
# SM_RESOURCE_CONFIG={"current_host":"algo-9","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"network_interface_name":"ethwe"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-9
# SM_MODULE_NAME=horovod_launcher
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_requirements":""},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-9","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"hyperparameters":{"checkpoint_path":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","evaluation_steps":1,"training_steps":1},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","job_name":"tf-horovod-12x-2018-11-25-11-19-08-954","log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz","module_name":"horovod_launcher","network_interface_name":"ethwe","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","resource_config":{"current_host":"algo-9","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"network_interface_name":"ethwe"},"user_entry_point":"horovod_launcher.py"}
# SM_USER_ARGS=["--checkpoint_path","s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","--evaluation_steps","1","--training_steps","1"]
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_EVALUATION_STEPS=1
# SM_HP_CHECKPOINT_PATH=s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints
# SM_HP_TRAINING_STEPS=1
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python horovod_launcher.py --checkpoint_path s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints --evaluation_steps 1 --training_steps 1
#
#
# 2018-11-25 11:22:41,031 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2018-11-25 11:22:41,034 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-25 11:22:41,326 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-25 11:22:41,338 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_requirements": ""
#     },
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-2",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4",
#         "algo-5",
#         "algo-6",
#         "algo-7",
#         "algo-8",
#         "algo-9",
#         "algo-10",
#         "algo-11",
#         "algo-12"
#     ],
#     "hyperparameters": {
#         "evaluation_steps": 1,
#         "checkpoint_path": "s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints",
#         "training_steps": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "job_name": "tf-horovod-12x-2018-11-25-11-19-08-954",
#     "log_level": 20,
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz",
#     "module_name": "horovod_launcher",
#     "network_interface_name": "ethwe",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "resource_config": {
#         "current_host": "algo-2",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3",
#             "algo-4",
#             "algo-5",
#             "algo-6",
#             "algo-7",
#             "algo-8",
#             "algo-9",
#             "algo-10",
#             "algo-11",
#             "algo-12"
#         ],
#         "network_interface_name": "ethwe"
#     },
#     "user_entry_point": "horovod_launcher.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"]
# SM_NETWORK_INTERFACE_NAME=ethwe
# SM_HPS={"checkpoint_path":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","evaluation_steps":1,"training_steps":1}
# SM_USER_ENTRY_POINT=horovod_launcher.py
# SM_FRAMEWORK_PARAMS={"sagemaker_requirements":""}
# SM_RESOURCE_CONFIG={"current_host":"algo-2","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"network_interface_name":"ethwe"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-2
# SM_MODULE_NAME=horovod_launcher
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_requirements":""},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-2","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"hyperparameters":{"checkpoint_path":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","evaluation_steps":1,"training_steps":1},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","job_name":"tf-horovod-12x-2018-11-25-11-19-08-954","log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz","module_name":"horovod_launcher","network_interface_name":"ethwe","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","resource_config":{"current_host":"algo-2","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"network_interface_name":"ethwe"},"user_entry_point":"horovod_launcher.py"}
# SM_USER_ARGS=["--checkpoint_path","s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","--evaluation_steps","1","--training_steps","1"]
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_EVALUATION_STEPS=1
# SM_HP_CHECKPOINT_PATH=s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints
# SM_HP_TRAINING_STEPS=1
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python horovod_launcher.py --checkpoint_path s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints --evaluation_steps 1 --training_steps 1
#
#
# MPI requested with process per hosts: 1
# MPI requested with process per hosts: 1
# Hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12'] current host: algo-9
# Inside Worker
# Worker node %s is waiting for MPI to start training process algo-9
# 2018-11-25 11:22:40,930 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2018-11-25 11:22:40,934 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-25 11:22:41,325 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-25 11:22:41,337 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_requirements": ""
#     },
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-12",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4",
#         "algo-5",
#         "algo-6",
#         "algo-7",
#         "algo-8",
#         "algo-9",
#         "algo-10",
#         "algo-11",
#         "algo-12"
#     ],
#     "hyperparameters": {
#         "evaluation_steps": 1,
#         "checkpoint_path": "s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints",
#         "training_steps": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "job_name": "tf-horovod-12x-2018-11-25-11-19-08-954",
#     "log_level": 20,
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz",
#     "module_name": "horovod_launcher",
#     "network_interface_name": "ethwe",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "resource_config": {
#         "current_host": "algo-12",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3",
#             "algo-4",
#             "algo-5",
#             "algo-6",
#             "algo-7",
#             "algo-8",
#             "algo-9",
#             "algo-10",
#             "algo-11",
#             "algo-12"
#         ],
#         "network_interface_name": "ethwe"
#     },
#     "user_entry_point": "horovod_launcher.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"]
# SM_NETWORK_INTERFACE_NAME=ethwe
# SM_HPS={"checkpoint_path":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","evaluation_steps":1,"training_steps":1}
# SM_USER_ENTRY_POINT=horovod_launcher.py
# SM_FRAMEWORK_PARAMS={"sagemaker_requirements":""}
# SM_RESOURCE_CONFIG={"current_host":"algo-12","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"network_interface_name":"ethwe"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-12
# SM_MODULE_NAME=horovod_launcher
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_requirements":""},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-12","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"hyperparameters":{"checkpoint_path":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","evaluation_steps":1,"training_steps":1},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","job_name":"tf-horovod-12x-2018-11-25-11-19-08-954","log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz","module_name":"horovod_launcher","network_interface_name":"ethwe","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","resource_config":{"current_host":"algo-12","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"network_interface_name":"ethwe"},"user_entry_point":"horovod_launcher.py"}
# SM_USER_ARGS=["--checkpoint_path","s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","--evaluation_steps","1","--training_steps","1"]
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_EVALUATION_STEPS=1
# SM_HP_CHECKPOINT_PATH=s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints
# SM_HP_TRAINING_STEPS=1
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python horovod_launcher.py --checkpoint_path s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints --evaluation_steps 1 --training_steps 1
#
#
# MPI requested with process per hosts: 1
# Hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12'] current host: algo-12
# Inside Worker
# Worker node %s is waiting for MPI to start training process algo-12
# 2018-11-25 11:22:41,605 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2018-11-25 11:22:41,608 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-25 11:22:41,964 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-25 11:22:41,976 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_requirements": ""
#     },
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-3",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4",
#         "algo-5",
#         "algo-6",
#         "algo-7",
#         "algo-8",
#         "algo-9",
#         "algo-10",
#         "algo-11",
#         "algo-12"
#     ],
#     "hyperparameters": {
#         "evaluation_steps": 1,
#         "checkpoint_path": "s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints",
#         "training_steps": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "job_name": "tf-horovod-12x-2018-11-25-11-19-08-954",
#     "log_level": 20,
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz",
#     "module_name": "horovod_launcher",
#     "network_interface_name": "ethwe",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "resource_config": {
#         "current_host": "algo-3",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3",
#             "algo-4",
#             "algo-5",
#             "algo-6",
#             "algo-7",
#             "algo-8",
#             "algo-9",
#             "algo-10",
#             "algo-11",
#             "algo-12"
#         ],
#         "network_interface_name": "ethwe"
#     },
#     "user_entry_point": "horovod_launcher.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"]
# SM_NETWORK_INTERFACE_NAME=ethwe
# SM_HPS={"checkpoint_path":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","evaluation_steps":1,"training_steps":1}
# SM_USER_ENTRY_POINT=horovod_launcher.py
# SM_FRAMEWORK_PARAMS={"sagemaker_requirements":""}
# SM_RESOURCE_CONFIG={"current_host":"algo-3","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"network_interface_name":"ethwe"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-3
# SM_MODULE_NAME=horovod_launcher
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_requirements":""},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-3","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"hyperparameters":{"checkpoint_path":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","evaluation_steps":1,"training_steps":1},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","job_name":"tf-horovod-12x-2018-11-25-11-19-08-954","log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz","module_name":"horovod_launcher","network_interface_name":"ethwe","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","resource_config":{"current_host":"algo-3","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"network_interface_name":"ethwe"},"user_entry_point":"horovod_launcher.py"}
# SM_USER_ARGS=["--checkpoint_path","s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","--evaluation_steps","1","--training_steps","1"]
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_EVALUATION_STEPS=1
# SM_HP_CHECKPOINT_PATH=s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints
# SM_HP_TRAINING_STEPS=1
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python horovod_launcher.py --checkpoint_path s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints --evaluation_steps 1 --training_steps 1
#
#
# Hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12'] current host: algo-2
# Inside Worker
# Worker node %s is waiting for MPI to start training process algo-2
# MPI requested with process per hosts: 1
# Hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12'] current host: algo-3
# Inside Worker
# Worker node %s is waiting for MPI to start training process algo-3
# 2018-11-25 11:22:41,957 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2018-11-25 11:22:41,962 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-25 11:22:42,331 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-25 11:22:42,343 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_requirements": ""
#     },
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4",
#         "algo-5",
#         "algo-6",
#         "algo-7",
#         "algo-8",
#         "algo-9",
#         "algo-10",
#         "algo-11",
#         "algo-12"
#     ],
#     "hyperparameters": {
#         "evaluation_steps": 1,
#         "checkpoint_path": "s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints",
#         "training_steps": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "job_name": "tf-horovod-12x-2018-11-25-11-19-08-954",
#     "log_level": 20,
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz",
#     "module_name": "horovod_launcher",
#     "network_interface_name": "ethwe",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3",
#             "algo-4",
#             "algo-5",
#             "algo-6",
#             "algo-7",
#             "algo-8",
#             "algo-9",
#             "algo-10",
#             "algo-11",
#             "algo-12"
#         ],
#         "network_interface_name": "ethwe"
#     },
#     "user_entry_point": "horovod_launcher.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"]
# SM_NETWORK_INTERFACE_NAME=ethwe
# SM_HPS={"checkpoint_path":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","evaluation_steps":1,"training_steps":1}
# SM_USER_ENTRY_POINT=horovod_launcher.py
# SM_FRAMEWORK_PARAMS={"sagemaker_requirements":""}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"network_interface_name":"ethwe"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=horovod_launcher
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_requirements":""},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"hyperparameters":{"checkpoint_path":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","evaluation_steps":1,"training_steps":1},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","job_name":"tf-horovod-12x-2018-11-25-11-19-08-954","log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz","module_name":"horovod_launcher","network_interface_name":"ethwe","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"network_interface_name":"ethwe"},"user_entry_point":"horovod_launcher.py"}
# SM_USER_ARGS=["--checkpoint_path","s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","--evaluation_steps","1","--training_steps","1"]
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_EVALUATION_STEPS=1
# SM_HP_CHECKPOINT_PATH=s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints
# SM_HP_TRAINING_STEPS=1
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python horovod_launcher.py --checkpoint_path s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints --evaluation_steps 1 --training_steps 1
#
#
# MPI requested with process per hosts: 1
# Hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12'] current host: algo-1
# Inside Master
# hosts that aren't SSHable yet: %s ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12']
# >>> Host: algo-2 is sshable now.
# >>> Host: algo-6 is sshable now.
# >>> Host: algo-9 is sshable now.
# >>> Host: algo-12 is sshable now.
# hosts that aren't SSHable yet: %s ['algo-1', 'algo-3', 'algo-4', 'algo-5', 'algo-7', 'algo-8', 'algo-10', 'algo-11']
# >>> Host: algo-1 is sshable now.
# hosts that aren't SSHable yet: %s ['algo-3', 'algo-4', 'algo-5', 'algo-7', 'algo-8', 'algo-10', 'algo-11']
# >>> Host: algo-3 is sshable now.
# >>> Host: algo-5 is sshable now.
# 2018-11-25 11:22:44,287 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2018-11-25 11:22:44,289 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-25 11:22:44,650 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-25 11:22:44,664 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_requirements": ""
#     },
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-4",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4",
#         "algo-5",
#         "algo-6",
#         "algo-7",
#         "algo-8",
#         "algo-9",
#         "algo-10",
#         "algo-11",
#         "algo-12"
#     ],
#     "hyperparameters": {
#         "evaluation_steps": 1,
#         "checkpoint_path": "s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints",
#         "training_steps": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "job_name": "tf-horovod-12x-2018-11-25-11-19-08-954",
#     "log_level": 20,
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz",
#     "module_name": "horovod_launcher",
#     "network_interface_name": "ethwe",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "resource_config": {
#         "current_host": "algo-4",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3",
#             "algo-4",
#             "algo-5",
#             "algo-6",
#             "algo-7",
#             "algo-8",
#             "algo-9",
#             "algo-10",
#             "algo-11",
#             "algo-12"
#         ],
#         "network_interface_name": "ethwe"
#     },
#     "user_entry_point": "horovod_launcher.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"]
# SM_NETWORK_INTERFACE_NAME=ethwe
# SM_HPS={"checkpoint_path":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","evaluation_steps":1,"training_steps":1}
# SM_USER_ENTRY_POINT=horovod_launcher.py
# SM_FRAMEWORK_PARAMS={"sagemaker_requirements":""}
# SM_RESOURCE_CONFIG={"current_host":"algo-4","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"network_interface_name":"ethwe"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-4
# SM_MODULE_NAME=horovod_launcher
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_requirements":""},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-4","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"hyperparameters":{"checkpoint_path":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","evaluation_steps":1,"training_steps":1},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","job_name":"tf-horovod-12x-2018-11-25-11-19-08-954","log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz","module_name":"horovod_launcher","network_interface_name":"ethwe","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","resource_config":{"current_host":"algo-4","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"network_interface_name":"ethwe"},"user_entry_point":"horovod_launcher.py"}
# SM_USER_ARGS=["--checkpoint_path","s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","--evaluation_steps","1","--training_steps","1"]
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_EVALUATION_STEPS=1
# SM_HP_CHECKPOINT_PATH=s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints
# SM_HP_TRAINING_STEPS=1
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python horovod_launcher.py --checkpoint_path s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints --evaluation_steps 1 --training_steps 1
#
#
# MPI requested with process per hosts: 1
# Hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12'] current host: algo-4
# Inside Worker
# Worker node %s is waiting for MPI to start training process algo-4
# 2018-11-25 11:22:41,480 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2018-11-25 11:22:41,484 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-25 11:22:41,825 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-25 11:22:41,836 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_requirements": ""
#     },
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-6",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4",
#         "algo-5",
#         "algo-6",
#         "algo-7",
#         "algo-8",
#         "algo-9",
#         "algo-10",
#         "algo-11",
#         "algo-12"
#     ],
#     "hyperparameters": {
#         "evaluation_steps": 1,
#         "checkpoint_path": "s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints",
#         "training_steps": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "job_name": "tf-horovod-12x-2018-11-25-11-19-08-954",
#     "log_level": 20,
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz",
#     "module_name": "horovod_launcher",
#     "network_interface_name": "ethwe",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "resource_config": {
#         "current_host": "algo-6",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3",
#             "algo-4",
#             "algo-5",
#             "algo-6",
#             "algo-7",
#             "algo-8",
#             "algo-9",
#             "algo-10",
#             "algo-11",
#             "algo-12"
#         ],
#         "network_interface_name": "ethwe"
#     },
#     "user_entry_point": "horovod_launcher.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"]
# SM_NETWORK_INTERFACE_NAME=ethwe
# SM_HPS={"checkpoint_path":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","evaluation_steps":1,"training_steps":1}
# SM_USER_ENTRY_POINT=horovod_launcher.py
# SM_FRAMEWORK_PARAMS={"sagemaker_requirements":""}
# SM_RESOURCE_CONFIG={"current_host":"algo-6","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"network_interface_name":"ethwe"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-6
# SM_MODULE_NAME=horovod_launcher
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_requirements":""},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-6","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"hyperparameters":{"checkpoint_path":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","evaluation_steps":1,"training_steps":1},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","job_name":"tf-horovod-12x-2018-11-25-11-19-08-954","log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz","module_name":"horovod_launcher","network_interface_name":"ethwe","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","resource_config":{"current_host":"algo-6","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"network_interface_name":"ethwe"},"user_entry_point":"horovod_launcher.py"}
# SM_USER_ARGS=["--checkpoint_path","s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","--evaluation_steps","1","--training_steps","1"]
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_EVALUATION_STEPS=1
# SM_HP_CHECKPOINT_PATH=s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints
# SM_HP_TRAINING_STEPS=1
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python horovod_launcher.py --checkpoint_path s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints --evaluation_steps 1 --training_steps 1
#
#
# MPI requested with process per hosts: 1
# Hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12'] current host: algo-6
# Inside Worker
# Worker node %s is waiting for MPI to start training process algo-6
# 2018-11-25 11:22:46,106 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2018-11-25 11:22:46,109 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-25 11:22:46,424 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-25 11:22:46,437 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_requirements": ""
#     },
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-11",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4",
#         "algo-5",
#         "algo-6",
#         "algo-7",
#         "algo-8",
#         "algo-9",
#         "algo-10",
#         "algo-11",
#         "algo-12"
#     ],
#     "hyperparameters": {
#         "evaluation_steps": 1,
#         "checkpoint_path": "s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints",
#         "training_steps": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "job_name": "tf-horovod-12x-2018-11-25-11-19-08-954",
#     "log_level": 20,
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz",
#     "module_name": "horovod_launcher",
#     "network_interface_name": "ethwe",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "resource_config": {
#         "current_host": "algo-11",
#         "hosts": [
#             "algo-1",
# ...
# SM_USER_ARGS=["--checkpoint_path","s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","--evaluation_steps","1","--training_steps","1"]
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_EVALUATION_STEPS=1
# SM_HP_CHECKPOINT_PATH=s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints
# SM_HP_TRAINING_STEPS=1
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python horovod_launcher.py --checkpoint_path s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints --evaluation_steps 1 --training_steps 1
#
#
# MPI requested with process per hosts: 1
# Hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12'] current host: algo-5
# Inside Worker
# Worker node %s is waiting for MPI to start training process algo-5
# Hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12'] current host: algo-10
# Inside Worker
# Worker node %s is waiting for MPI to start training process algo-10
# hosts that aren't SSHable yet: %s ['algo-8', 'algo-10', 'algo-11']
# >>> Host: algo-8 is sshable now.
# >>> Host: algo-11 is sshable now.
# hosts that aren't SSHable yet: %s ['algo-10']
# >>> Host: algo-10 is sshable now.
# Env Hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12'] Hosts: ['algo-1', 'algo-2', 'algo-3', 'algo-4', 'algo-5', 'algo-6', 'algo-7', 'algo-8', 'algo-9', 'algo-10', 'algo-11', 'algo-12'] process_per_hosts: 1 num_processes: 12
# network interface name: %s ethwe
# MPI Command: mpirun --host algo-1,algo-2,algo-3,algo-4,algo-5,algo-6,algo-7,algo-8,algo-9,algo-10,algo-11,algo-12 -np 12  --allow-run-as-root --display-map --tag-output -mca btl_tcp_if_include ethwe -mca oob_tcp_if_include ethwe -x NCCL_SOCKET_IFNAME=ethwe --mca plm_rsh_no_tree_spawn 1 -mca orte_abort_on_non_zero_status 1 -x NCCL_MIN_NRINGS=8 -x NCCL_DEBUG=INFO -x LD_LIBRARY_PATH -x PATH -x LD_PRELOAD=/libchangehostname.so -x SM_HOSTS="["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"]" -x SM_NETWORK_INTERFACE_NAME="ethwe" -x SM_HPS="{"checkpoint_path":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","evaluation_steps":1,"training_steps":1}" -x SM_USER_ENTRY_POINT="horovod_launcher.py" -x SM_FRAMEWORK_PARAMS="{"sagemaker_requirements":""}" -x SM_RESOURCE_CONFIG="{"current_host":"algo-1","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"network_interface_name":"ethwe"}" -x SM_INPUT_DATA_CONFIG="{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}" -x SM_OUTPUT_DATA_DIR="/opt/ml/output/data" -x SM_CHANNELS="["test","train"]" -x SM_CURRENT_HOST="algo-1" -x SM_MODULE_NAME="horovod_launcher" -x SM_LOG_LEVEL="20" -x SM_FRAMEWORK_MODULE="sagemaker_tensorflow_container.training:main" -x SM_INPUT_DIR="/opt/ml/input" -x SM_INPUT_CONFIG_DIR="/opt/ml/input/config" -x SM_OUTPUT_DIR="/opt/ml/output" -x SM_NUM_CPUS="4" -x SM_NUM_GPUS="0" -x SM_MODEL_DIR="/opt/ml/model" -x SM_MODULE_DIR="s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz" -x SM_TRAINING_ENV="{"additional_framework_parameters":{"sagemaker_requirements":""},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current
# MPI Command: mpirun --host algo-1,algo-2,algo-3,algo-4,algo-5,algo-6,algo-7,algo-8,algo-9,algo-10,algo-11,algo-12 -np 12  --allow-run-as-root --display-map --tag-output -mca btl_tcp_if_include ethwe -mca oob_tcp_if_include ethwe -x NCCL_SOCKET_IFNAME=ethwe --mca plm_rsh_no_tree_spawn 1 -mca orte_abort_on_non_zero_status 1 -x NCCL_MIN_NRINGS=8 -x NCCL_DEBUG=INFO -x LD_LIBRARY_PATH -x PATH -x LD_PRELOAD=/libchangehostname.so -x SM_HOSTS="["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"]" -x SM_NETWORK_INTERFACE_NAME="ethwe" -x SM_HPS="{"checkpoint_path":"s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints","evaluation_steps":1,"training_steps":1}" -x SM_USER_ENTRY_POINT="horovod_launcher.py" -x SM_FRAMEWORK_PARAMS="{"sagemaker_requirements":""}" -x SM_RESOURCE_CONFIG="{"current_host":"algo-1","hosts":["algo-1","algo-2","algo-3","algo-4","algo-5","algo-6","algo-7","algo-8","algo-9","algo-10","algo-11","algo-12"],"network_interface_name":"ethwe"}" -x SM_INPUT_DATA_CONFIG="{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}" -x SM_OUTPUT_DATA_DIR="/opt/ml/output/data" -x SM_CHANNELS="["test","train"]" -x SM_CURRENT_HOST="algo-1" -x SM_MODULE_NAME="horovod_launcher" -x SM_LOG_LEVEL="20" -x SM_FRAMEWORK_MODULE="sagemaker_tensorflow_container.training:main" -x SM_INPUT_DIR="/opt/ml/input" -x SM_INPUT_CONFIG_DIR="/opt/ml/input/config" -x SM_OUTPUT_DIR="/opt/ml/output" -x SM_NUM_CPUS="4" -x SM_NUM_GPUS="0" -x SM_MODEL_DIR="/opt/ml/model" -x SM_MODULE_DIR="s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/source/sourcedir.tar.gz" -x SM_TRAINING_ENV="{"additional_framework_parameters":{"sagemaker_requirements":""},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current
# Running user script:
#
# %s #!/usr/bin/env bash
# touch /mpi_is_running
# /usr/bin/python train_mnist_hvd.py --checkpoint_path s3://sagemaker-us-west-2-964029418868/tf-horovod-12x-2018-11-25-11-19-08-954/checkpoints --evaluation_steps 1 --training_steps 1 --test /opt/ml/input/data/test --train /opt/ml/input/data/train
# EXIT_CODE=$?
# touch /mpi_is_finished
# exit ${EXIT_CODE}
#
# Warning: Permanently added 'algo-7,10.38.0.3' (ECDSA) to the list of known hosts.#015
# Warning: Permanently added 'algo-2,10.35.0.3' (ECDSA) to the list of known hosts.#015
# Warning: Permanently added 'algo-6,10.44.0.3' (ECDSA) to the list of known hosts.#015
# Warning: Permanently added 'algo-12,10.34.0.3' (ECDSA) to the list of known hosts.#015
# Warning: Permanently added 'algo-4,10.32.0.4' (ECDSA) to the list of known hosts.#015
# Warning: Permanently added 'algo-11,10.33.0.3' (ECDSA) to the list of known hosts.#015
# Warning: Permanently added 'algo-3,10.39.0.3' (ECDSA) to the list of known hosts.#015
# Warning: Permanently added 'algo-9,10.36.0.3' (ECDSA) to the list of known hosts.#015
# Warning: Permanently added 'algo-5,10.42.0.3' (ECDSA) to the list of known hosts.#015
# Warning: Permanently added 'algo-8,10.46.0.3' (ECDSA) to the list of known hosts.#015
# Warning: Permanently added 'algo-10,10.34.128.3' (ECDSA) to the list of known hosts.#015
#  Data for JOB [34197,1] offset 0 Total slots allocated 12
#
#  ========================   JOB MAP   ========================
#
#  Data for node: aws#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [34197,1] App: 0 Process rank: 0 Bound: N/A
#
#  Data for node: algo-2#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [34197,1] App: 0 Process rank: 1 Bound: N/A
#
#  Data for node: algo-3#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [34197,1] App: 0 Process rank: 2 Bound: N/A
#
#  Data for node: algo-4#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [34197,1] App: 0 Process rank: 3 Bound: N/A
#
#  Data for node: algo-5#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [34197,1] App: 0 Process rank: 4 Bound: N/A
#
#  Data for node: algo-6#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [34197,1] App: 0 Process rank: 5 Bound: N/A
#
#  Data for node: algo-7#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [34197,1] App: 0 Process rank: 6 Bound: N/A
#
#  Data for node: algo-8#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [34197,1] App: 0 Process rank: 7 Bound: N/A
#
#  Data for node: algo-9#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [34197,1] App: 0 Process rank: 8 Bound: N/A
#
#  Data for node: algo-10#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [34197,1] App: 0 Process rank: 9 Bound: N/A
#
#  Data for node: algo-11#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [34197,1] App: 0 Process rank: 10 Bound: N/A
#
#  Data for node: algo-12#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [34197,1] App: 0 Process rank: 11 Bound: N/A
#
#  =============================================================
# [1,0]<stderr>:Using TensorFlow backend.
# MPI started training process on worker node %s algo-5
# [1,4]<stderr>:2018-11-25 11:22:54.383120: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# [1,11]<stderr>:2018-11-25 11:22:54.385492: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# [1,3]<stderr>:2018-11-25 11:22:54.390092: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# [1,6]<stderr>:2018-11-25 11:22:54.382557: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# [1,7]<stderr>:2018-11-25 11:22:54.382717: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# [1,5]<stderr>:2018-11-25 11:22:54.389125: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# [1,8]<stderr>:2018-11-25 11:22:54.386434: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# [1,10]<stderr>:2018-11-25 11:22:54.386287: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# [1,9]<stderr>:2018-11-25 11:22:54.385824: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# [1,3]<stdout>:Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# [1,7]<stdout>:Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# [1,6]<stdout>:Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# [1,10]<stdout>:Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# [1,0]<stderr>:2018-11-25 11:22:54.384508: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# [1,4]<stdout>:Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# [1,1]<stderr>:2018-11-25 11:22:54.387853: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# [1,11]<stdout>:Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# [1,0]<stdout>:Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# [1,2]<stderr>:2018-11-25 11:22:54.386242: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# [1,1]<stdout>:Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# [1,5]<stdout>:Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# [1,2]<stdout>:Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# [1,8]<stdout>:Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# [1,9]<stdout>:Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 2018-11-25 11:22:46 Training - Training image download completed. Training in progress.
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/sagemaker/logs.py in multi_stream_iter(client, log_group, streams, positions)
#      96     event_iters = [log_stream(client, log_group, s, positions[s].timestamp, positions[s].skip) for s in streams]
# ---> 97     events = [next(s) if s else None for s in event_iters]
#      98
#
# /anaconda3/lib/python3.7/site-packages/sagemaker/logs.py in <listcomp>(.0)
#      96     event_iters = [log_stream(client, log_group, s, positions[s].timestamp, positions[s].skip) for s in streams]
# ---> 97     events = [next(s) if s else None for s in event_iters]
#      98
#
# StopIteration:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-54-3d230bf586f5> in <module>()
#      12                        source_dir=source_dir)
#      13
# ---> 14 estimator.fit({'train': train_input, 'test': test_input})
#
# /anaconda3/lib/python3.7/site-packages/sagemaker/tensorflow/estimator.py in fit(self, inputs, wait, logs, job_name, run_tensorboard_locally)
#     259                 tensorboard.join()
#     260         else:
# --> 261             fit_super()
#     262
#     263     @classmethod
#
# /anaconda3/lib/python3.7/site-packages/sagemaker/tensorflow/estimator.py in fit_super()
#     241
#     242         def fit_super():
# --> 243             super(TensorFlow, self).fit(inputs, wait, logs, job_name)
#     244
#     245         if run_tensorboard_locally and wait is False:
#
# /anaconda3/lib/python3.7/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name)
#     209         self.latest_training_job = _TrainingJob.start_new(self, inputs)
#     210         if wait:
# --> 211             self.latest_training_job.wait(logs=logs)
#     212
#     213     @classmethod
#
# /anaconda3/lib/python3.7/site-packages/sagemaker/estimator.py in wait(self, logs)
#     470     def wait(self, logs=True):
#     471         if logs:
# --> 472             self.sagemaker_session.logs_for_job(self.job_name, wait=True)
#     473         else:
#     474             self.sagemaker_session.wait_for_job(self.job_name)
#
# /anaconda3/lib/python3.7/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll)
#     900                     print('')
#     901                     dot = False
# --> 902                 for idx, event in sagemaker.logs.multi_stream_iter(client, log_group, stream_names, positions):
#     903                     color_wrap(idx, event['message'])
#     904                     ts, count = positions[stream_names[idx]]
#
# RuntimeError: generator raised StopIteration
