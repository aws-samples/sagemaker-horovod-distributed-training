# %% [markdown]
# # Horovod Distributed Training with SageMaker TensorFlow script mode.

# %% [markdown]
# Horovod is a distributed training framework based on Message Passing Interfae (MPI). For information about Horovod, see [Horovod README](https://github.com/uber/horovod).
#
# You can perform distributed training with Horovod on SageMaker by using the SageMaker Tensorflow container. If MPI is enabled when you create the training job, SageMaker creates the MPI environment and executes the `mpirun` command to execute the training script. Details on how to configure mpi settings in training job are described later in this example.
#
# In this example notebook, we create a Horovod training job that uses the MNIST data set.

# %% [markdown]
# ## Set up the environment
#
# We get the `IAM` role that this notebook is running as and pass that role to the TensorFlow estimator that SageMaker uses to get data and perform training.

# %%
import sagemaker
import os
from sagemaker.utils import sagemaker_timestamp
from sagemaker.tensorflow import TensorFlow
from sagemaker import get_execution_role
import time

sagemaker_session = sagemaker.Session()

default_s3_bucket = sagemaker_session.default_bucket()
sagemaker_iam_role = get_execution_role()

train_script = "mnist_hvd.py"
instance_count = 2

# %% [markdown]
# ## Prepare Data for training
#
# Now we download the MNIST dataset to the local `/tmp/data/` directory and then upload it to an S3 bucket. After uploading the dataset to S3, we delete the data from `/tmp/data/`.

# %%
import os
import shutil

import numpy as np

import keras
from keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

s3_train_path = "s3://{}/mnist/train.npz".format(default_s3_bucket)
s3_test_path = "s3://{}/mnist/test.npz".format(default_s3_bucket)

# Create local directory
! mkdir -p /tmp/data/mnist_train
! mkdir -p /tmp/data/mnist_test

# Save data locally
np.savez('/tmp/data/mnist_train/train.npz', data=x_train, labels=y_train)
np.savez('/tmp/data/mnist_test/test.npz', data=x_test, labels=y_test)

# Upload the dataset to s3
! aws s3 cp /tmp/data/mnist_train/train.npz $s3_train_path
! aws s3 cp /tmp/data/mnist_test/test.npz $s3_test_path

print('training data at ', s3_train_path)
print('test data at ', s3_test_path)
! rm -rf /tmp/data
# Out:
# upload: ../../../../tmp/data/mnist_train/train.npz to s3://sagemaker-us-east-1-328296961357/mnist/train.npz
# upload: ../../../../tmp/data/mnist_test/test.npz to s3://sagemaker-us-east-1-328296961357/mnist/test.npz
# training data at  s3://sagemaker-us-east-1-328296961357/mnist/train.npz
# test data at  s3://sagemaker-us-east-1-328296961357/mnist/test.npz

# %% [markdown]
# ## Write a script for horovod distributed training
#
# This example is based on the [Keras MNIST horovod example](https://github.com/uber/horovod/blob/master/examples/keras_mnist.py) example in the horovod github repository.
#
# To run this script we have to make following modifications:

# %% [markdown]
# ### 1. Accept `--model_dir` as a command-line argument
# Modify the script to accept `model_dir` as a command-line argument that defines the directory path (i.e. `/opt/ml/model/`) where the output model is saved. Because Sagemaker deletes the training cluster when training completes, saving the model to `/opt/ml/model/` directory prevents the trained model from getting lost, because when the training job completes, SageMaker writes the data stored in `/opt/ml/model/` to an S3 bucket.
#
# This also allows the SageMaker training job to integrate with other SageMaker services, such as hosted inference endpoints or batch transform jobs. It also allows you to host the trained model outside of SageMaker.
#
# The following code adds `model_dir` as a command-line argument to the script:
#
# ```
# parser = argparse.ArgumentParser()
# parser.add_argument('--model_dir', type=str)
# ```
#
# More details can be found [here](https://github.com/aws/sagemaker-containers/blob/master/README.md).

# %% [markdown]
# ### 2. Load train and test data
#
# You can get local directory path where the `train` and `test` data is downloaded by reading the environment variable `SM_CHANNEL_TRAIN` and `SM_CHANNEL_TEST` respectively.
# After you get the directory path, load the data into memory.
#
# Here is the code:
#
# ```
# x_train = np.load(os.path.join(os.environ['SM_CHANNEL_TRAIN'], 'train.npz'))['data']
# y_train = np.load(os.path.join(os.environ['SM_CHANNEL_TRAIN'], 'train.npz'))['labels']
#
# x_test = np.load(os.path.join(os.environ['SM_CHANNEL_TEST'], 'test.npz'))['data']
# y_test = np.load(os.path.join(os.environ['SM_CHANNEL_TEST'], 'test.npz'))['labels']
# ```
#
# For a list of all environment variables set by SageMaker that are accessible inside a training script, see [SageMaker Containers](https://github.com/aws/sagemaker-containers/blob/master/README.md).

# %% [markdown]
# ### 3. Save the model only at the master node
#
# Because in Horovod the training is distributed to multiple nodes, the model should only be saved by the master node. The following code in the script does this:
#
# ```
# # Horovod: Save model only on worker 0 (i.e. master)
# if hvd.rank() == 0:
#     saved_model_path = tf.contrib.saved_model.save_keras_model(model, args.model_dir)
# ```

# %% [markdown]
# ### Training script
#
# Here is the final training script.

# %%
# !cat 'mnist_hvd.py'
# Out:
# #     Copyright 2019 Amazon.com, Inc. or its affiliates. All Rights Reserved.
# #
# #     Licensed under the Apache License, Version 2.0 (the "License").
# #     You may not use this file except in compliance with the License.
# #     A copy of the License is located at
# #
# #         https://aws.amazon.com/apache-2-0/
# #
# #     or in the "license" file accompanying this file. This file is distributed
# #     on an "AS IS" BASIS, WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either
# #     express or implied. See the License for the specific language governing
# #     permissions and limitations under the License.
#
# from __future__ import print_function
#
# import argparse
# import os
#
# import numpy as np
#
# # import tensorflow.keras as keras
# from tensorflow.keras.datasets import mnist
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Dropout, Flatten
# from tensorflow.keras.layers import Conv2D, MaxPooling2D
# from tensorflow.keras import backend as K
# import math
# import tensorflow as tf
# import horovod.tensorflow.keras as hvd
#
# if __name__ == '__main__':
#
#     num_gpus = int(os.environ['SM_NUM_GPUS'])
#
#     parser = argparse.ArgumentParser()
#
#     # Data, model, and output directories. These are required.
#     parser.add_argument('--output-dir', type=str, default=os.environ['SM_OUTPUT_DIR'])
#     parser.add_argument('--model_dir', type=str)
#     parser.add_argument('--train', type=str, default=os.environ['SM_CHANNEL_TRAIN'])
#     parser.add_argument('--test', type=str, default=os.environ['SM_CHANNEL_TEST'])
#
#     args, _ = parser.parse_known_args()
#
#     # Horovod: initialize Horovod.
#     hvd.init()
#
#     # Horovod: pin GPU to be used to process local rank (one GPU per process)
#     config = tf.ConfigProto()
#     config.gpu_options.allow_growth = True
#     config.gpu_options.visible_device_list = str(hvd.local_rank())
#     K.set_session(tf.Session(config=config))
#
#     batch_size = 128
#     num_classes = 10
#
#     # Horovod: adjust number of epochs based on number of GPUs.
#     epochs = int(math.ceil(12.0 / hvd.size()))
#
#     # Input image dimensions
#     img_rows, img_cols = 28, 28
#
#     # The data, shuffled and split between train and test sets
#
#     x_train = np.load(os.path.join(args.train, 'train.npz'))['data']
#     y_train = np.load(os.path.join(args.train, 'train.npz'))['labels']
#     print("Train dataset loaded from: {}".format(os.path.join(args.train, 'train.npz')))
#
#     x_test = np.load(os.path.join(args.test, 'test.npz'))['data']
#     y_test = np.load(os.path.join(args.test, 'test.npz'))['labels']
#     print("Test dataset loaded from: {}".format(os.path.join(args.test, 'test.npz')))
#
#
#     if K.image_data_format() == 'channels_first':
#         x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
#         x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
#         input_shape = (1, img_rows, img_cols)
#     else:
#         x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
#         x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
#         input_shape = (img_rows, img_cols, 1)
#
#     x_train = x_train.astype('float32')
#     x_test = x_test.astype('float32')
#     x_train /= 255
#     x_test /= 255
#     print('x_train shape:', x_train.shape)
#     print(x_train.shape[0], 'train samples')
#     print(x_test.shape[0], 'test samples')
#
#     # Convert class vectors to binary class matrices
#     y_train = tf.keras.utils.to_categorical(y_train, num_classes)
#     y_test = tf.keras.utils.to_categorical(y_test, num_classes)
#
#     model = Sequential()
#     model.add(Conv2D(32, kernel_size=(3, 3),
#                      activation='relu',
#                      input_shape=input_shape))
#     model.add(Conv2D(64, (3, 3), activation='relu'))
#     model.add(MaxPooling2D(pool_size=(2, 2)))
#     model.add(Dropout(0.25))
#     model.add(Flatten())
#     model.add(Dense(128, activation='relu'))
#     model.add(Dropout(0.5))
#     model.add(Dense(num_classes, activation='softmax'))
#
#     # Horovod: adjust learning rate based on number of GPUs.
#     opt = tf.keras.optimizers.Adadelta(1.0 * hvd.size())
#
#     # Horovod: add Horovod Distributed Optimizer.
#     opt = hvd.DistributedOptimizer(opt)
#
#     model.compile(loss=tf.keras.losses.categorical_crossentropy,
#                   optimizer=opt,
#                   metrics=['accuracy'])
#
#     callbacks = [
#         # Horovod: broadcast initial variable states from rank 0 to all other processes.
#         # This is necessary to ensure consistent initialization of all workers when
#         # training is started with random weights or restored from a checkpoint.
#         hvd.callbacks.BroadcastGlobalVariablesCallback(0),
#     ]
#
#     # Horovod: save checkpoints only on worker 0 to prevent other workers from corrupting them.
#     if hvd.rank() == 0:
#         callbacks.append(tf.keras.callbacks.ModelCheckpoint('./checkpoint-{epoch}.h5'))
#
#     model.fit(x_train, y_train,
#               batch_size=batch_size,
#               callbacks=callbacks,
#               epochs=epochs,
#               verbose=1,
#               validation_data=(x_test, y_test))
#     score = model.evaluate(x_test, y_test, verbose=0)
#
#     print('Test loss:', score[0])
#     print('Test accuracy:', score[1])
#
#     # Horovod: Save model only on worker 0 (i.e. master)
#     if hvd.rank() == 0:
#         saved_model_path = tf.contrib.saved_model.save_keras_model(model, args.model_dir)
#         print("Model successfully saved at: {}".format(saved_model_path))

# %% [markdown]
# ## Test locally using SageMaker Python SDK TensorFlow Estimator
#
# You can use the SageMaker Python SDK TensorFlow estimator to easily train locally and in SageMaker.
#
# This notebook shows how to use the SageMaker Python SDK to run your code in a local container before deploying to SageMaker's managed training or hosting environments. Just change your estimator's `train_instance_type` to `local` or `local_gpu`. For more information, see: https://github.com/aws/sagemaker-python-sdk#local-mode.
#
# To use this feature, you need to install docker-compose (and nvidia-docker if you are training with a GPU). Run the following script to install docker-compose or nvidia-docker-compose, and configure the notebook environment for you.
#
# **Note**: You can only run a single local notebook at a time.

# %%
# !/bin/bash ./setup.sh
# Out:
# /bin/bash: ./setup.sh: No such file or directory

# %% [markdown]
# To train locally, set `train_instance_type` to `local`:

# %%
train_instance_type='local'

# %% [markdown]
# The MPI environment for Horovod can be configured by setting the following flags in the `mpi` field of the `distribution` dictionary that you pass to the TensorFlow estimator :
#
# * ``enabled (bool)``: If set to ``True``, the MPI setup is performed and ``mpirun`` command is executed.
# * ``processes_per_host (int) [Optional]``: Number of processes MPI should launch on each host. Note, this should not be greater than the available slots on the selected instance type. This flag should be set for the multi-cpu/gpu training.
# * ``custom_mpi_options (str) [Optional]``: Any mpirun flag(s) can be passed in this field that will be added to the mpirun command executed by SageMaker to launch distributed horovod training.
#
# For more information about the `distribution` dictionary, see the SageMaker Python SDK [README](https://github.com/aws/sagemaker-python-sdk/blob/v1.17.3/src/sagemaker/tensorflow/README.rst).
#
# First, enable MPI:

# %%
distributions = {'mpi': {'enabled': True}}

# %% [markdown]
# Now, we create the Tensorflow estimator passing the `train_instance_type` and `distribution`

# %%
estimator_local = TensorFlow(entry_point=train_script,
                       role=sagemaker_iam_role,
                       train_instance_count=instance_count,
                       train_instance_type=train_instance_type,
                       script_mode=True,
                       framework_version='1.12',
                       distributions=distributions,
                       base_job_name='hvd-mnist-local')
# Out:
# tensorflow py2 container will be deprecated soon.

# %% [markdown]
# Call `fit()` to start the local training

# %%
#%%time
#estimator_local.fit({"train":s3_train_path, "test":s3_test_path})

# %% [markdown]
# ## Train in SageMaker
#
# After you test the training job locally, run it on SageMaker:
#
# First, change the instance type from `local` to the valid EC2 instance type. For example, `ml.c4.xlarge`.

# %%
#train_instance_type='ml.c4.xlarge' #4  vCPU
train_instance_type='ml.c4.4xlarge' #16 vCPU

# %% [markdown]
# You can also provide your custom MPI options by passing in the `custom_mpi_options` field of `distribution` dictionary that will be added to the `mpirun` command executed by SageMaker:

# %%
distributions = {'mpi': {'enabled': True, "custom_mpi_options": "-verbose --NCCL_DEBUG=INFO"}}

# %% [markdown]
# Now, we create the Tensorflow estimator passing the `train_instance_type` and `distribution` to launch the training job in sagemaker.

# %%
estimator = TensorFlow(entry_point=train_script,
                       role=sagemaker_iam_role,
                       train_instance_count=instance_count,
                       train_instance_type=train_instance_type,
                       script_mode=True,
                       framework_version='1.12',
                       distributions=distributions,
                       base_job_name='hvd-mnist')
# Out:
# tensorflow py2 container will be deprecated soon.

# %% [markdown]
# Call `fit()` to start the training

# %%
#%%time
#estimator.fit({"train":s3_train_path, "test":s3_test_path})

# %% [markdown]
# ##  Horovod training in SageMaker using multiple CPU/GPU

# %% [markdown]
# To enable mulitiple CPUs or GPUs for horovod training, set the `processes_per_host` field in the `mpi` section of the `distribution` dictionary to the desired value of processes that will be executed per instance.

# %%
#distributions = {'mpi': {'enabled': True, "processes_per_host": 2}}

distributions = {'mpi': {'enabled': True, 
                         "custom_mpi_options": "-verbose --NCCL_DEBUG=INFO -x OMPI_MCA_btl_vader_single_copy_mechanism=none", 
                         "processes_per_host":8}}

# %% [markdown]
# Now, we create the Tensorflow estimator passing the `train_instance_type` and `distribution`

# %%
estimator = TensorFlow(entry_point=train_script,
                       role=sagemaker_iam_role,
                       train_instance_count=instance_count,
                       train_instance_type=train_instance_type,
                       script_mode=True,
                       framework_version='1.12', #1.12
                       distributions=distributions,
                       base_job_name='hvd-mnist-multi-cpu')
# Out:
# tensorflow py2 container will be deprecated soon.

# %% [markdown]
# Call `fit()` to start the training

# %%
# %%time
estimator.fit({"train":s3_train_path, "test":s3_test_path})
# Out:
# 2019-06-05 21:22:55 Starting - Starting the training job...
# 2019-06-05 21:22:59 Starting - Launching requested ML instances.........
# 2019-06-05 21:24:35 Starting - Preparing the instances for training......
# 2019-06-05 21:25:54 Downloading - Downloading input data
# 2019-06-05 21:25:54 Training - Downloading the training image.
# 2019-06-05 21:26:00,221 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2019-06-05 21:26:00,227 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-06-05 21:26:00,667 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-06-05 21:26:00,677 sagemaker-containers INFO     Starting MPI run as worker node.
# 2019-06-05 21:26:00,677 sagemaker-containers INFO     Waiting for MPI Master to create SSH daemon.
# 2019-06-05 21:26:00,679 sagemaker-containers INFO     Cannot connect to host algo-1
# 2019-06-05 21:26:00,679 sagemaker-containers INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 10.32.0.3
# 2019-06-05 21:26:01,686 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.2p2)
# /usr/local/lib/python2.7/dist-packages/paramiko/kex_ecdh_nist.py:39: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   m.add_string(self.Q_C.public_numbers().encode_point())
# /usr/local/lib/python2.7/dist-packages/paramiko/kex_ecdh_nist.py:96: CryptographyDeprecationWarning: Support for unsafe construction of public numbers from encoded data will be removed in a future version. Please use EllipticCurvePublicKey.from_encoded_point
#   self.curve, Q_S_bytes
# /usr/local/lib/python2.7/dist-packages/paramiko/kex_ecdh_nist.py:111: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   hm.add_string(self.Q_C.public_numbers().encode_point())
# 2019-06-05 21:26:01,853 paramiko.transport INFO     Authentication (publickey) successful!
# 2019-06-05 21:26:01,920 sagemaker-containers INFO     Can connect to host algo-1
# 2019-06-05 21:26:01,921 sagemaker-containers INFO     MPI Master online, creating SSH daemon.
# 2019-06-05 21:26:01,928 sagemaker-containers INFO     Waiting for MPI process to finish.
# 2019-06-05 21:26:00,445 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2019-06-05 21:26:00,451 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-06-05 21:26:01,010 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-06-05 21:26:01,021 sagemaker-containers INFO     Starting MPI run as worker node.
# 2019-06-05 21:26:01,021 sagemaker-containers INFO     Creating SSH daemon.
# 2019-06-05 21:26:01,027 sagemaker-containers INFO     Waiting for MPI workers to establish their SSH connections
# 2019-06-05 21:26:01,028 sagemaker-containers INFO     Cannot connect to host algo-2
# 2019-06-05 21:26:01,029 sagemaker-containers INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 10.40.0.2
# 2019-06-05 21:26:02,036 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.2p2)
# /usr/local/lib/python2.7/dist-packages/paramiko/kex_ecdh_nist.py:39: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   m.add_string(self.Q_C.public_numbers().encode_point())
# /usr/local/lib/python2.7/dist-packages/paramiko/kex_ecdh_nist.py:96: CryptographyDeprecationWarning: Support for unsafe construction of public numbers from encoded data will be removed in a future version. Please use EllipticCurvePublicKey.from_encoded_point
#   self.curve, Q_S_bytes
# /usr/local/lib/python2.7/dist-packages/paramiko/kex_ecdh_nist.py:111: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   hm.add_string(self.Q_C.public_numbers().encode_point())
# 2019-06-05 21:26:02,237 paramiko.transport INFO     Authentication (publickey) successful!
# 2019-06-05 21:26:02,281 sagemaker-containers INFO     Can connect to host algo-2
# 2019-06-05 21:26:02,282 sagemaker-containers INFO     Worker algo-2 available for communication
# 2019-06-05 21:26:02,282 sagemaker-containers INFO     Env Hosts: [u'algo-1', u'algo-2'] Hosts: [u'algo-1:8', u'algo-2:8'] process_per_hosts: 8 num_processes: 16
# 2019-06-05 21:26:02,285 sagemaker-containers INFO     Network interface name: ethwe
# 2019-06-05 21:26:02,292 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2019-06-05 21:26:02,303 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "module_dir": "s3://sagemaker-us-east-1-328296961357/hvd-mnist-multi-cpu-2019-06-05-21-22-55-178/source/sourcedir.tar.gz",
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "resource_config": {
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "ethwe",
#         "current_host": "algo-1"
#     },
#     "num_cpus": 16,
#     "log_level": 20,
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "input_config_dir": "/opt/ml/input/config",
#     "additional_framework_parameters": {
#         "sagemaker_mpi_enabled": true,
#         "sagemaker_mpi_custom_mpi_options": "-verbose --NCCL_DEBUG=INFO -x OMPI_MCA_btl_vader_single_copy_mechanism=none",
#         "sagemaker_mpi_num_of_processes_per_host": 8
#     },
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "model_dir": "/opt/ml/model",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "master_hostname": "algo-1",
#     "hyperparameters": {
#         "model_dir": "/opt/ml/model"
#     },
#     "network_interface_name": "ethwe",
#     "num_gpus": 0,
#     "input_dir": "/opt/ml/input",
#     "user_entry_point": "mnist_hvd.py",
#     "job_name": "hvd-mnist-multi-cpu-2019-06-05-21-22-55-178",
#     "current_host": "algo-1",
#     "is_master": true,
#     "module_name": "mnist_hvd",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "RecordWrapperType": "None",
#             "S3DistributionType": "FullyReplicated"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "RecordWrapperType": "None",
#             "S3DistributionType": "FullyReplicated"
#         }
#     },
#     "framework_module": "sagemaker_tensorflow_container.training:main"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_INPUT_DIR=/opt/ml/input
# SM_USER_ENTRY_POINT=mnist_hvd.py
# SM_MODULE_NAME=mnist_hvd
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_mpi_custom_mpi_options":"-verbose --NCCL_DEBUG=INFO -x OMPI_MCA_btl_vader_single_copy_mechanism=none","sagemaker_mpi_enabled":true,"sagemaker_mpi_num_of_processes_per_host":8},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"model_dir":"/opt/ml/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"hvd-mnist-multi-cpu-2019-06-05-21-22-55-178","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-328296961357/hvd-mnist-multi-cpu-2019-06-05-21-22-55-178/source/sourcedir.tar.gz","module_name":"mnist_hvd","network_interface_name":"ethwe","num_cpus":16,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"ethwe"},"user_entry_point":"mnist_hvd.py"}
# SM_CHANNELS=["test","train"]
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_NETWORK_INTERFACE_NAME=ethwe
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_USER_ARGS=["--model_dir","/opt/ml/model"]
# SM_CURRENT_HOST=algo-1
# SM_MODEL_DIR=/opt/ml/model
# SM_NUM_GPUS=0
# SM_MODULE_DIR=s3://sagemaker-us-east-1-328296961357/hvd-mnist-multi-cpu-2019-06-05-21-22-55-178/source/sourcedir.tar.gz
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=16
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_HPS={"model_dir":"/opt/ml/model"}
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_FRAMEWORK_PARAMS={"sagemaker_mpi_custom_mpi_options":"-verbose --NCCL_DEBUG=INFO -x OMPI_MCA_btl_vader_single_copy_mechanism=none","sagemaker_mpi_enabled":true,"sagemaker_mpi_num_of_processes_per_host":8}
# SM_HP_MODEL_DIR=/opt/ml/model
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"ethwe"}
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python2.7:/usr/lib/python2.7/plat-x86_64-linux-gnu:/usr/lib/python2.7/lib-tk:/usr/lib/python2.7/lib-old:/usr/lib/python2.7/lib-dynload:/usr/local/lib/python2.7/dist-packages:/usr/lib/python2.7/dist-packages
# SM_LOG_LEVEL=20
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
#
# Invoking script with the following command:
#
# mpirun --host algo-1:8,algo-2:8 -np 16 --allow-run-as-root --display-map --tag-output -mca btl_tcp_if_include ethwe -mca oob_tcp_if_include ethwe -mca plm_rsh_no_tree_spawn 1 -bind-to socket -map-by slot -mca pml ob1 -mca btl ^openib -mca orte_abort_on_non_zero_status 1 -x NCCL_MIN_NRINGS=4 -x NCCL_SOCKET_IFNAME=ethwe -x NCCL_DEBUG=INFO -x LD_LIBRARY_PATH -x PATH -x LD_PRELOAD=/usr/local/lib/python2.7/dist-packages/gethostname.so -verbose -x OMPI_MCA_btl_vader_single_copy_mechanism=none -x SM_HOSTS -x SM_INPUT_DIR -x SM_USER_ENTRY_POINT -x SM_MODULE_NAME -x SM_TRAINING_ENV -x SM_CHANNELS -x SM_INPUT_DATA_CONFIG -x SM_NETWORK_INTERFACE_NAME -x SM_CHANNEL_TEST -x SM_USER_ARGS -x SM_CURRENT_HOST -x SM_MODEL_DIR -x SM_NUM_GPUS -x SM_MODULE_DIR -x SM_OUTPUT_DIR -x SM_NUM_CPUS -x SM_FRAMEWORK_MODULE -x SM_HPS -x SM_OUTPUT_INTERMEDIATE_DIR -x SM_FRAMEWORK_PARAMS -x SM_HP_MODEL_DIR -x SM_INPUT_CONFIG_DIR -x SM_RESOURCE_CONFIG -x PYTHONPATH -x SM_LOG_LEVEL -x SM_CHANNEL_TRAIN -x SM_OUTPUT_DATA_DIR /usr/bin/python -m mpi4py mnist_hvd.py --model_dir /opt/ml/model
#
#
# Warning: Permanently added 'algo-2,10.40.0.2' (ECDSA) to the list of known hosts.#015
# --------------------------------------------------------------------------
# WARNING: a request was made to bind a process. While the system
# supports binding the process itself, at least one node does NOT
# support binding memory to the process location.
#
#   Node:  aws
#
# Open MPI uses the "hwloc" library to perform process and memory
# binding. This error message means that hwloc has indicated that
# processor binding support is not available on this machine.
#
# On OS X, processor and memory binding is not available at all (i.e.,
# the OS does not expose this functionality).
#
# On Linux, lack of the functionality can mean that you are on a
# platform where processor and memory affinity is not supported in Linux
#  Data for JOB [34186,1] offset 0 Total slots allocated 16
#
#  ========================   JOB MAP   ========================
#
#  Data for node: aws#011Num slots: 8#011Max slots: 0#011Num procs: 8
#  #011Process OMPI jobid: [34186,1] App: 0 Process rank: 0 Bound: UNBOUND
#  #011Process OMPI jobid: [34186,1] App: 0 Process rank: 1 Bound: UNBOUND
#  #011Process OMPI jobid: [34186,1] App: 0 Process rank: 2 Bound: UNBOUND
#  #011Process OMPI jobid: [34186,1] App: 0 Process rank: 3 Bound: UNBOUND
#  #011Process OMPI jobid: [34186,1] App: 0 Process rank: 4 Bound: UNBOUND
#  #011Process OMPI jobid: [34186,1] App: 0 Process rank: 5 Bound: UNBOUND
# itself, or that hwloc was built without NUMA and/or processor affinity
# support. When building hwloc (which, depending on your Open MPI
# installation, may be embedded in Open MPI itself), it is important to
# have the libnuma header and library files available. Different linux
# distributions package these files under different names; look for
# packages with the word "numa" in them. You may also need a developer
# version of the package (e.g., with "dev" or "devel" in the name) to
# obtain the relevant header files.
#
# If you are getting this message on a non-OS X, non-Linux platform,
# then hwloc does not support processor / memory affinity on this
# platform. If the OS/platform does actually support processor / memory
# affinity, then you should contact the hwloc maintainers:
# https://github.com/open-mpi/hwloc.
#
# This is a warning only; your job will continue, though performance may
# be degraded.
# --------------------------------------------------------------------------
#  #011Process OMPI jobid: [34186,1] App: 0 Process rank: 6 Bound: UNBOUND
#  #011Process OMPI jobid: [34186,1] App: 0 Process rank: 7 Bound: UNBOUND
#
#  Data for node: algo-2#011Num slots: 8#011Max slots: 0#011Num procs: 8
#  #011Process OMPI jobid: [34186,1] App: 0 Process rank: 8 Bound: N/A
#  #011Process OMPI jobid: [34186,1] App: 0 Process rank: 9 Bound: N/A
#  #011Process OMPI jobid: [34186,1] App: 0 Process rank: 10 Bound: N/A
#  #011Process OMPI jobid: [34186,1] App: 0 Process rank: 11 Bound: N/A
#  #011Process OMPI jobid: [34186,1] App: 0 Process rank: 12 Bound: N/A
#  #011Process OMPI jobid: [34186,1] App: 0 Process rank: 13 Bound: N/A
#  #011Process OMPI jobid: [34186,1] App: 0 Process rank: 14 Bound: N/A
#  #011Process OMPI jobid: [34186,1] App: 0 Process rank: 15 Bound: N/A
#
#  =============================================================
# [1,9]<stderr>:2019-06-05 21:26:04.325333: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2.Tune using inter_op_parallelism_threads for best performance.
# [1,10]<stderr>:2019-06-05 21:26:04.326235: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2.Tune using inter_op_parallelism_threads for best performance.
# [1,11]<stderr>:2019-06-05 21:26:04.326363: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2.Tune using inter_op_parallelism_threads for best performance.
# [1,13]<stderr>:2019-06-05 21:26:04.326587: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2.Tune using inter_op_parallelism_threads for best performance.
# [1,15]<stderr>:2019-06-05 21:26:04.326711: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2.Tune using inter_op_parallelism_threads for best performance.
# [1,12]<stderr>:2019-06-05 21:26:04.326829: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2.Tune using inter_op_parallelism_threads for best performance.
# [1,14]<stderr>:2019-06-05 21:26:04.327053: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2.Tune using inter_op_parallelism_threads for best performance.
# [1,8]<stderr>:2019-06-05 21:26:04.327183: I tensorflow/core/common_runtime/process_util.cc:71] Creating new thread pool with default inter op setting: 2.Tune using inter_op_parallelism_threads for best performance.
# [1,11]<stdout>:Train dataset loaded from: /opt/ml/input/data/train/train.npz
# [1,12]<stdout>:Train dataset loaded from: /opt/ml/input/data/train/train.npz
# [1,13]<stdout>:Train dataset loaded from: /opt/ml/input/data/train/train.npz
# [1,15]<stdout>:Train dataset loaded from: /opt/ml/input/data/train/train.npz
# [1,14]<stdout>:Train dataset loaded from: /opt/ml/input/data/train/train.npz
# [1,8]<stdout>:Train dataset loaded from: /opt/ml/input/data/train/train.npz
# [1,9]<stdout>:Train dataset loaded from: /opt/ml/input/data/train/train.npz
# [1,10]<stdout>:Train dataset loaded from: /opt/ml/input/data/train/train.npz
# [1,11]<stdout>:Test dataset loaded from: /opt/ml/input/data/test/test.npz
# [1,12]<stdout>:Test dataset loaded from: /opt/ml/input/data/test/test.npz
# [1,13]<stdout>:Test dataset loaded from: /opt/ml/input/data/test/test.npz
# [1,15]<stdout>:Test dataset loaded from: /opt/ml/input/data/test/test.npz
# [1,14]<stdout>:Test dataset loaded from: /opt/ml/input/data/test/test.npz
# [1,8]<stdout>:Test dataset loaded from: /opt/ml/input/data/test/test.npz
# [1,9]<stdout>:Test dataset loaded from: /opt/ml/input/data/test/test.npz
# [1,10]<stdout>:Test dataset loaded from: /opt/ml/input/data/test/test.npz
# [1,8]<stdout>:x_train shape: (60000, 28, 28, 1)
# [1,8]<stdout>:60000 train samples
# [1,8]<stdout>:10000 test samples
# [1,11]<stdout>:x_train shape: (60000, 28, 28, 1)
# [1,11]<stdout>:60000 train samples
# [1,11]<stdout>:10000 test samples
# [1,13]<stdout>:x_train shape: (60000, 28, 28, 1)
# [1,13]<stdout>:60000 train samples
# [1,13]<stdout>:10000 test samples
# [1,12]<stdout>:x_train shape: (60000, 28, 28, 1)
# [1,12]<stdout>:60000 train samples
# [1,12]<stdout>:10000 test samples
# [1,14]<stdout>:x_train shape: (60000, 28, 28, 1)
# [1,14]<stdout>:60000 train samples
# [1,14]<stdout>:10000 test samples
# [1,15]<stdout>:x_train shape: (60000, 28, 28, 1)
# [1,15]<stdout>:60000 train samples
# [1,15]<stdout>:10000 test samples
# [1,9]<stdout>:x_train shape: (60000, 28, 28, 1)
# [1,9]<stdout>:60000 train samples
# [1,9]<stdout>:10000 test samples
# [1,10]<stdout>:x_train shape: (60000, 28, 28, 1)
# [1,10]<stdout>:60000 train samples
# [1,10]<stdout>:10000 test samples
# [1,7]<stdout>:Train dataset loaded from: /opt/ml/input/data/train/train.npz
# [1,1]<stdout>:Train dataset loaded from: /opt/ml/input/data/train/train.npz
# [1,3]<stdout>:Train dataset loaded from: /opt/ml/input/data/train/train.npz
# [1,2]<stdout>:Train dataset loaded from: /opt/ml/input/data/train/train.npz
# [1,5]<stdout>:Train dataset loaded from: /opt/ml/input/data/train/train.npz
# [1,0]<stdout>:Train dataset loaded from: /opt/ml/input/data/train/train.npz
# [1,4]<stdout>:Train dataset loaded from: /opt/ml/input/data/train/train.npz
# [1,6]<stdout>:Train dataset loaded from: /opt/ml/input/data/train/train.npz
# [1,7]<stdout>:Test dataset loaded from: /opt/ml/input/data/test/test.npz
# [1,6]<stdout>:Test dataset loaded from: /opt/ml/input/data/test/test.npz
# [1,1]<stdout>:Test dataset loaded from: /opt/ml/input/data/test/test.npz
# [1,3]<stdout>:Test dataset loaded from: /opt/ml/input/data/test/test.npz
# [1,2]<stdout>:Test dataset loaded from: /opt/ml/input/data/test/test.npz
# [1,0]<stdout>:Test dataset loaded from: /opt/ml/input/data/test/test.npz
# [1,5]<stdout>:Test dataset loaded from: /opt/ml/input/data/test/test.npz
# [1,4]<stdout>:Test dataset loaded from: /opt/ml/input/data/test/test.npz
# [1,15]<stdout>:Train on 60000 samples, validate on 10000 samples
# [1,12]<stdout>:Train on 60000 samples, validate on 10000 samples
# [1,11]<stdout>:Train on 60000 samples, validate on 10000 samples
# [1,9]<stdout>:Train on 60000 samples, validate on 10000 samples
# [1,10]<stdout>:Train on 60000 samples, validate on 10000 samples
# [1,14]<stdout>:Train on 60000 samples, validate on 10000 samples
# [1,13]<stdout>:Train on 60000 samples, validate on 10000 samples
# [1,8]<stdout>:Train on 60000 samples, validate on 10000 samples
# [1,3]<stdout>:x_train shape: (60000, 28, 28, 1)
# [1,3]<stdout>:60000 train samples
# [1,3]<stdout>:10000 [1,3]<stdout>:test samples
# [1,2]<stdout>:x_train shape: (60000, 28, 28, 1)
# [1,2]<stdout>:60000 train samples
# [1,2]<stdout>:10000 test samples
# [1,0]<stdout>:x_train shape: (60000, 28, 28, 1)
# [1,0]<stdout>:60000 train samples
# [1,0]<stdout>:10000 test samples
# [1,5]<stdout>:x_train shape: (60000, 28, 28, 1)
# [1,5]<stdout>:60000 train samples
# [1,5]<stdout>:10000 test samples
# [1,7]<stdout>:x_train shape: (60000, 28, 28, 1[1,7]<stdout>:)
# [1,7]<stdout>:60000 train samples
# [1,7]<stdout>:10000 test samples
# [1,4]<stdout>:x_train shape: (60000, 28, 28, 1)
# [1,4]<stdout>:60000 train samples
# [1,4]<stdout>:10000 test samples
# [1,6]<stdout>:x_train shape: (60000, 28, 28, 1)
# [1,6]<stdout>:60000 train samples
# [1,6]<stdout>:10000 test samples
# [1,1]<stdout>:x_train shape: (60000, 28, 28, 1)[1,1]<stdout>:
# [1,1]<stdout>:60000 train samples
# [1,1]<stdout>:10000 test samples[1,1]<stdout>:
# [aws:00051] 1 more process has sent help message help-orte-rmaps-base.txt / rmaps:membind-not-supported
# [aws:00051] Set MCA parameter "orte_base_help_aggregate" to 0 to see all help / error messages
# [1,5]<stdout>:Train on 60000 samples, validate on 10000 samples
# [1,0]<stdout>:Train on 60000 samples, validate on 10000 samples
# [1,2]<stdout>:Train on 60000 samples, validate on 10000 samples
# [1,7]<stdout>:Train on 60000 samples, validate on 10000 samples
# [1,6]<stdout>:Train on 60000 samples, validate on 10000 samples
# [1,1]<stdout>:Train on 60000 samples, validate on 10000 samples
# [1,3]<stdout>:Train on 60000 samples, validate on 10000 samples
# [1,4]<stdout>:Train on 60000 samples, validate on 10000 samples
# 2019-06-05 21:26:06 Training - Training image download completed. Training in progress.[1,0]<stdout>:Epoch 1/1
# [1,5]<stdout>:Epoch 1/1
# [1,10]<stdout>:Epoch 1/1
# [1,9]<stdout>:Epoch 1/1
# [1,12]<stdout>:Epoch 1/1
# [1,8]<stdout>:Epoch 1/1
# [1,13]<stdout>:Epoch 1/1
# [1,15]<stdout>:Epoch 1/1
# [1,11]<stdout>:Epoch 1/1
# [1,2]<stdout>:Epoch 1/1
# [1,14]<stdout>:Epoch 1/1
# [1,3]<stdout>:Epoch 1/1
# [1,6]<stdout>:Epoch 1/1
# [1,1]<stdout>:Epoch 1/1
# [1,7]<stdout>:Epoch 1/1
# [1,4]<stdout>:Epoch 1/1
# [1,5]<stdout>:#015  128/60000 [..............................][1,5]<stdout>: - ETA: 1:00:38 - loss: 2.3149 - acc: 0.1172[1,15]<stdout>:#015  128/60000 [..............................] - ETA: 1:00:37 - loss: 2.3211 - acc: 0.0859[1,12]<stdout>:#015  128/60000 [..............................] - ETA: 1:00:37 - loss: 2.2892 - acc: 0.1094[1,13]<stdout>:#015  128/60000 [..............................] - ETA: 1:00:37 - loss: 2.3034 - acc: 0.0703[1,14]<stdout>:#015  128/60000 [..............................] - ETA: 1:00:30 - loss: 2.3165 - acc: 0.0625[1,10]<stdout>:#015  128/60000 [..............................] - ETA: 1:00:37 - loss: 2.3146 - acc: 0.0547[1,11]<stdout>:#015  128/60000 [..............................] - ETA: 1:00:37 - loss: 2.3225 - acc: 0.0703[1,0]<stdout>:#015[1,0]<stdout>:  128/60000 [..............................][1,8]<stdout>:#015  128/60000 [..............................] - ETA: 1:00:38 - loss: 2.2976 - acc: 0.1328[1,0]<stdout>: - ETA: 1:00:41 - loss: 2.3078 - acc: 0.0938[1,9]<stdout>:#015  128/60000 [..............................] - ETA: 1:00:38 - loss: 2.3084 - acc: 0.0625[1,7]<stdout>:#015[1,7]<stdout>:  128/60000 [..............................][1,7]<stdout>: - ETA: 1:00:24 - loss: 2.3094 - acc: 0.0547[1,2]<stdout>:#015[1,2]<stdout>:  128/60000 [..............................][1,2]<stdout>: - ETA: 1:00:36 - loss: 2.3174 - acc: 0.1328[1,3]<stdout>:#015[1,3]<stdout>:  128/60000 [..............................][1,3]<stdout>: - ETA: 1:00:31 - loss: 2.3068 - acc: 0.1094[1,1]<stdout>:#015[1,1]<stdout>:  128/60000 [..............................][1,1]<stdout>: - ETA: 1:00:28 - loss: 2.3109 - acc: 0.1016[1,4]<stdout>:#015[1,6]<stdout>:#015  128/60000 [..............................] - ETA: 1:00:30 - loss: 2.3159 - acc: 0.0938[1,4]<stdout>:  128/60000 [..............................] - ETA: 1:00:25 - loss: 2.3230 - acc: 0.0938[1,15]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  256/60000 [..............................] - ETA: 35:55 - loss: 2.5791 - acc: 0.1328  [1,12]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  256/60000 [..............................] - ETA: 35:55 - loss: 2.6132 - acc: 0.1211  [1,14]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  256/60000 [..............................] - ETA: 35:51 - loss: 2.5717 - acc: 0.1250  [1,13]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  256/60000 [..............................] - ETA: 35:55 - loss: 2.4618 - acc: 0.1445  [1,11]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01 ...
# t>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  768/60000 [..............................] - ETA: 18:38 - loss: 2.3617 - acc: 0.1823[1,4]<stdout>:  768/60000 [..............................][1,4]<stdout>: - ETA: 18:37 - loss: 2.3692 - acc: 0.1862[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  768/60000 [..............................] - ETA: 18:40 - loss: 2.3199 - acc: 0.1849[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  768/60000 [..............................] - ETA: 18:38 - loss: 2.3410 - acc: 0.2070[1,2]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  768/60000 [..............................] - ETA: 18:39 - loss: 2.3512 - acc: 0.1797[1,3]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  768/60000 [..............................] - ETA: 18:38 - loss: 2.3637 - acc: 0.1888[1,4]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  896/60000 [..............................][1,12]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  896/60000 [..............................] - ETA: 17:15 - loss: 2.6683 - acc: 0.1830[1,15]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  896/60000 [..............................] - ETA: 17:15 - loss: 2.7277 - acc: 0.1853[1,11]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0 ...
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1408/60000 [..............................] - ETA: 14:22 - loss: 2.6908 - acc: 0.2109[1,13]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1536/60000 [..............................] - ETA: 14:00 - loss: 2.6080 - acc: 0.2227[1,12]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1536/60000 [..............................] - ETA: 14:00 - loss: 2.6813 - acc: 0.2109[1,3]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,3]<stdout>: 1536/60000 [..............................][1,3]<stdout>: - ETA: 14:00 - loss: 2.6344 - acc: 0.2207[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1536/60000 [..............................][1,0]<stdout>: - ETA: 14:01 - loss: 2.5260 - acc: 0.2259[1,14]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1536/60000 [..............................] - ETA: 14:00 - loss: 2.6209 - acc: 0.2272[1,2]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1536/60000 [..............................][1,2]<stdout>: - ETA: 14:00 - loss: 2.6642 - acc: 0.2142[1,7]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,7]<stdout>: 1536/60000 [..............................][1,7]<stdout>: - ETA: 14:00 - loss: 2.6545 - acc: 0.2350[1,5]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1536/60000 [............ ...
# ......................] - ETA: 12:38 - loss: 2.5570 - acc: 0.2348[1,15]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2176/60000 [>.............................] - ETA: 12:38 - loss: 2.5598 - acc: 0.2463[1,11]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2176/60000 [>.............................] - ETA: 12:38 - loss: 2.6076 - acc: 0.2238[1,2]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2176/60000 [>.............................][1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010[1,0]<stdout>:#015[1,0]<stdout>: 2176/60000 [>.............................][1,0]<stdout>: - ETA: 12:38 - loss: 2.4957 - acc: 0.2403[1,2]<stdout>: - ETA: 12:38 - loss: 2.6100 - acc: 0.2394[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2176/60000 [>.............................][1,1]<stdout>: - ETA: 12:37 - loss: 2.5328 - acc: 0.2564[1,4]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2176/60000 [>.............................] - ETA: 12:37 - loss: 2.5711 - acc: 0.2440[1,9]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2176/60000 [>.............................] - ETA: 12:38 - loss: 2.5823 - acc: 0.2376[1,8]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2176/60000 [>.............................] - ETA: 12:38 - loss: 2.5709 - acc: 0.2403[1,10]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010 ...
# s: 2.3881 - acc: 0.3022[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2816/60000 [>.............................] - ETA: 11:57 - loss: 2.2787 - acc: 0.2987[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010[1,5]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010[1,4]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,4]<stdout>: 2816/60000 [>.............................][1,1]<stdout>:#015 2816/60000 [>.............................] - ETA: 11:56 - loss: 2.3179 - acc: 0.3026[1,6]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2816/60000 [>.............................] - ETA: 11:57 - loss: 2.3506 - acc: 0.3001[1,3]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2816/60000 [>.............................] - ETA: 11:57 - loss: 2.3773 - acc: 0.2887[1,5]<stdout>:#015 2816/60000 [>.............................] - ETA: 11:57 - loss: 2.3468 - acc: 0.2912[1,4]<stdout>: - ETA: 11:56 - loss: 2.3413 - acc: 0.3004[1,2]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2816/60000 [>.............................] - ETA: 11:57 - loss: 2.3592 - acc: 0.2962[1,15]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2816/60000 [>.............................] - ETA: 11:57 - loss: 2.3500 - acc: 0.2990[1,12]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010# ...
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,6]<stdout>: 3456/60000 [>.............................][1,6]<stdout>: - ETA: 11:21 - loss: 2.1507 - acc: 0.3545[1,7]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3456/60000 [>.............................][1,7]<stdout>: - ETA: 11:21 - loss: 2.1692 - acc: 0.3640[1,5]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3456/60000 [>.............................][1,5]<stdout>: - ETA: 11:22 - loss: 2.1400 - acc: 0.3504[1,4]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3456/60000 [>.............................][1,4]<stdout>: - ETA: 11:21 - loss: 2.1391 - acc: 0.3608[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3584/60000 [>.............................][1,15]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3584/60000 [>.............................] - ETA: 11:18 - loss: 2.1030 - acc: 0.3672[1,13]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3584/60000 [>.............................] - ETA: 11:18 - loss: 2.0745 - acc: 0.3666[1,0]<stdout>: - ETA: 11:18 - loss: 2.0361 - acc: 0.3758[1,12]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3584/60000 [>.............................] - ETA: 11:18 - loss: 2.1319 - acc: 0.3541[1,10]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 358 ...
# ...
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01559392/60000 [============================>.] - ETA: 6s - loss: 0.2665 - acc: 0.9195[1,8]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01559392/60000 [============================>.] - ETA: 6s - loss: 0.2643 - acc: 0.9215[1,10]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01559392/60000 [============================>.] - ETA: 6s - loss: 0.2614 - acc: 0.9215[1,7]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,7]<stdout>:59392/60000 [============================>.][1,9]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01559392/60000 [============================>.] - ETA: 6s - loss: 0.2639 - acc: 0.9216[1,14]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01559392/60000 [============================>.] - ETA: 6s - loss: 0.2603 - acc: 0.9212[1,6]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01559392/60000 [============================>.] - ETA: 6s - loss: 0.2632 - acc: 0.9208[1,7]<stdout>: - ETA: 6s - loss: 0.2636 - acc: 0.9214[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01559392/60000 [============================>.][1,0]<stdout>: - ETA: 6s - loss: 0.2609 - acc: 0.9218[1,13]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01559392/60000 [============================>.] - ETA: 6s - loss: 0.2627 - acc: 0.9203[1,15]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010# ...
# [1,6]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010[1,6]<stdout>:#015[1,6]<stdout>:60000/60000 [==============================][1,6]<stdout>: - 636s 11ms/step - loss: 0.2611 - acc: 0.9214 - val_loss: 0.0348 - val_acc: 0.9901
# [1,3]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01560000/60000 [==============================][1,3]<stdout>: - 636s 11ms/step - loss: 0.2617 - acc: 0.9206 - val_loss: 0.0348 - val_acc: 0.9901
# [1,2]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01560000/60000 [==============================][1,2]<stdout>: - 636s 11ms/step - loss: 0.2638 - acc: 0.9201 - val_loss: 0.0348 - val_acc: 0.9901
# [1,7]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01560000/60000 [==============================][1,7]<stdout>: - 636s 11ms/step - loss: 0.2614 - acc: 0.9219 - val_loss: 0.0348 - val_acc: 0.9901
# [1,4]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01560000/60000 [==============================][1,4]<stdout>: - 636s 11ms/step - loss: 0.2620 - acc: 0.9211 - val_loss: 0.0348 - val_acc: 0.9901
# [1,5]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010[1,5]<stdout>:#015[1,5]<stdout>:60000/60000 [==============================][1,5]<stdout>: - 636s 11ms/step - loss: 0.2629 - acc: 0.9202 - val_loss: 0.0348 - val_acc: 0.9901
# [1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01560000/60000 [==============================][1,0]<stdout>: - 637s 11ms/step - loss: 0.2588 - acc: 0.9224 - val_loss: 0.0348 - val_acc: 0.9901
# [1,13]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01560000/60000 [==============================] - 641s 11ms/step - loss: 0.2608 - acc: 0.9209 - val_loss: 0.0348 - val_acc: 0.9901
# [1,8]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01560000/60000 [==============================] - 642s 11ms/step - loss: 0.2621 - acc: 0.9221 - val_loss: 0.0348 - val_acc: 0.9901
# [1,11]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01560000/60000 [==============================] - 644s 11ms/step - loss: 0.2612 - acc: 0.9209 - val_loss: 0.0348 - val_acc: 0.9901
# [1,14]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01560000/60000 [==============================] - 645s 11ms/step - loss: 0.2582 - acc: 0.9219 - val_loss: 0.0348 - val_acc: 0.9901
# [1,12]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01560000/60000 [==============================] - 646s 11ms/step - loss: 0.2644 - acc: 0.9201 - val_loss: 0.0348 - val_acc: 0.9901
# [1,15]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01560000/60000 [==============================] - 647s 11ms/step - loss: 0.2616 - acc: 0.9213 - val_loss: 0.0348 - val_acc: 0.9901
# [1,9]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01560000/60000 [==============================] - 647s 11ms/step - loss: 0.2620 - acc: 0.9222 - val_loss: 0.0348 - val_acc: 0.9901
# [1,10]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01560000/60000 [==============================] - 647s 11ms/step - loss: 0.2592 - acc: 0.9221 - val_loss: 0.0348 - val_acc: 0.9901
# [1,6]<stdout>:Test loss:[1,6]<stdout>: [1,6]<stdout>:0.034847617274543885[1,6]<stdout>:
# [1,6]<stdout>:Test accuracy:[1,6]<stdout>: [1,6]<stdout>:0.9901
# [1,3]<stdout>:Test loss:[1,3]<stdout>: [1,3]<stdout>:0.034847617274543885[1,3]<stdout>:
# [1,3]<stdout>:Test accuracy:[1,3]<stdout>: 0.9901[1,3]<stdout>:
# [1,2]<stdout>:Test loss:[1,2]<stdout>: [1,2]<stdout>:0.034847617274543885[1,2]<stdout>:
# [1,2]<stdout>:Test accuracy: 0.9901
# [1,7]<stdout>:Test loss: 0.034847617274543885
# [1,7]<stdout>:Test accuracy: 0.9901
# [1,1]<stdout>:Test loss: 0.034847617274543885
# [1,1]<stdout>:Test accuracy: 0.9901
# [1,5]<stdout>:Test loss: 0.034847617274543885
# [1,5]<stdout>:Test accuracy: 0.9901
# [1,0]<stdout>:Test loss: 0.034847617274543885
# [1,0]<stdout>:Test accuracy: 0.9901
# [1,4]<stdout>:Test loss: 0.034847617274543885
# [1,4]<stdout>:Test accuracy: 0.9901
# [1,0]<stderr>:WARNING:tensorflow:This model was compiled with a Keras optimizer (<horovod._keras.Adadelta object at 0x7f24e011abd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
# [1,0]<stderr>:
# [1,0]<stderr>:Consider using a TensorFlow optimizer from `tf.train`.
# [1,0]<stderr>:WARNING:tensorflow:Model was compiled with an optimizer, but the optimizer is not from `tf.train` (e.g. `tf.train.AdagradOptimizer`). Only the serving graph was exported. The train and evaluate graphs were not added to the SavedModel.
# [1,0]<stdout>:Model successfully saved at: /opt/ml/model/temp-1559770626
# [1,14]<stdout>:Test loss: 0.034847617274543885
# [1,14]<stdout>:Test accuracy: 0.9901
# [1,13]<stdout>:Test loss: 0.034847617274543885
# [1,13]<stdout>:Test accuracy: 0.9901
# [1,8]<stdout>:Test loss: 0.034847617274543885
# [1,8]<stdout>:Test accuracy: 0.9901
# [1,11]<stdout>:Test loss: 0.034847617274543885
# [1,11]<stdout>:Test accuracy: 0.9901
# [1,12]<stdout>:Test loss: 0.034847617274543885
# [1,12]<stdout>:Test accuracy: 0.9901
# [1,9]<stdout>:Test loss: 0.034847617274543885
# [1,9]<stdout>:Test accuracy: 0.9901
# [1,10]<stdout>:Test loss: 0.034847617274543885
# [1,10]<stdout>:Test accuracy: 0.9901
# [1,15]<stdout>:Test loss: 0.034847617274543885
# [1,15]<stdout>:Test accuracy: 0.9901
# 2019-06-05 21:37:23,902 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2019-06-05 21:38:04 Uploading - Uploading generated training model
# 2019-06-05 21:38:04 Completed - Training job completed
# 2019-06-05 21:37:53,941 sagemaker-containers INFO     MPI process finished.
# 2019-06-05 21:37:53,941 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://github.com/aws/sagemaker-python-sdk/tree/master/src/sagemaker/tensorflow#adapting-your-local-tensorflow-script
# 2019-06-05 21:37:53,941 sagemaker-containers INFO     Reporting training SUCCESS
# Billable seconds: 1488
# CPU times: user 2.42 s, sys: 51.8 ms, total: 2.47 s
# Wall time: 15min 26s

# %% [markdown]
# ## Improving horovod training performance on SageMaker
#
# Performing Horovod training inside a VPC improves the network latency between nodes, leading to higher performance and stability of Horovod training jobs.
#
# For a detailed explanation of how to configure a VPC for SageMaker training, see [Secure Training and Inference with VPC](https://github.com/aws/sagemaker-python-sdk#secure-training-and-inference-with-vpc).

# %% [markdown]
# ### Setup VPC infrastructure
# We will setup following resources as part of VPC stack:
# * `VPC`: AWS Virtual private cloud with CIDR block.
# * `Subnets`: Two subnets with the CIDR blocks `10.0.0.0/24` and `10.0.1.0/24`
# * `Security Group`: Defining the open ingress and egress ports, such as TCP.
# * `VpcEndpoint`: S3 Vpc endpoint allowing sagemaker's vpc cluster to dosenload data from S3.
# * `Route Table`: Defining routes and is tied to subnets and VPC.
#
# Complete cloud formation template for setting up the VPC stack can be seen [here](./vpc_infra_cfn.json).

# %%
print(sagemaker_iam_role)
import boto3
from botocore.exceptions import ClientError
from time import sleep

def create_vpn_infra(stack_name="hvdvpcstack"):
    cfn = boto3.client("cloudformation")

    cfn_template = open("vpc_infra_cfn.json", "r").read()
    
    try:
        vpn_stack = cfn.create_stack(StackName=(stack_name),
                                     TemplateBody=cfn_template)
    except ClientError as e:
        if e.response['Error']['Code'] == 'AlreadyExistsException':
            print("Stack: {} already exists, so skipping stack creation.".format(stack_name))
        else:
            print("Unexpected error: %s" % e)
            raise e

    describe_stack = cfn.describe_stacks(StackName=stack_name)["Stacks"][0]

    while describe_stack["StackStatus"] == "CREATE_IN_PROGRESS":
        describe_stack = cfn.describe_stacks(StackName=stack_name)["Stacks"][0]
        sleep(0.5)

    if describe_stack["StackStatus"] != "CREATE_COMPLETE":
        raise ValueError("Stack creation failed in state: {}".format(describe_stack["StackStatus"]))

    print("Stack: {} created successfully with status: {}".format(stack_name, describe_stack["StackStatus"]))

    subnets = []
    security_groups = []

    for output_field in describe_stack["Outputs"]:

        if output_field["OutputKey"] == "SecurityGroupId":
            security_groups.append(output_field["OutputValue"])
        if output_field["OutputKey"] == "Subnet1Id" or output_field["OutputKey"] == "Subnet2Id":
            subnets.append(output_field["OutputValue"])

    return subnets, security_groups


subnets, security_groups = create_vpn_infra()
print("Subnets: {}".format(subnets))
print("Security Groups: {}".format(security_groups))
# Out:
# arn:aws:iam::328296961357:role/service-role/AmazonSageMaker-ExecutionRole-20190430T072462
# Stack: hvdvpcstack created successfully with status: CREATE_COMPLETE
# Subnets: ['subnet-06ebce2df1c3f0303', 'subnet-0bdaf2d5c019f21c9']
# Security Groups: ['sg-01f003850777a9140']

# %% [markdown]
# ### VPC training in SageMaker
# Now, we create the Tensorflow estimator, passing the `train_instance_type` and `distribution`.

# %%
estimator = TensorFlow(entry_point=train_script,
                       role=sagemaker_iam_role,
                       train_instance_count=instance_count,
                       train_instance_type=train_instance_type,
                       script_mode=True,
                       framework_version='1.12',
                       distributions=distributions,
                       security_group_ids=['sg-01f003850777a9140'],
                       subnets=['subnet-06ebce2df1c3f0303', 'subnet-0bdaf2d5c019f21c9'],
                       base_job_name='hvd-mnist-vpc')
# Out:
# tensorflow py2 container will be deprecated soon.

# %% [markdown]
# Call `fit()` to start the training

# %%
estimator.fit({"train":s3_train_path, "test":s3_test_path})
# Out:
# 2019-06-06 02:37:10 Starting - Starting the training job...
# 2019-06-06 02:37:15 Starting - Launching requested ML instances......

# %% [markdown]
# After training is completed, you can host the saved model by using TensorFlow Serving on SageMaker. For an example that uses TensorFlow Serving, see [(https://github.com/awslabs/amazon-sagemaker-examples/blob/master/sagemaker-python-sdk/tensorflow_serving_container/tensorflow_serving_container.ipynb](https://github.com/awslabs/amazon-sagemaker-examples/blob/master/sagemaker-python-sdk/tensorflow_serving_container/tensorflow_serving_container.ipynb).

# %% [markdown]
# ## Reference Links:
# * [SageMaker Container MPI Support.](https://github.com/aws/sagemaker-containers/blob/master/src/sagemaker_containers/_mpi.py)
# * [Horovod Official Documentation](https://github.com/uber/horovod)
# * [SageMaker Tensorflow script mode example.](https://github.com/awslabs/amazon-sagemaker-examples/blob/master/sagemaker-python-sdk/tensorflow_script_mode_quickstart/tensorflow_script_mode_quickstart.ipynb)
